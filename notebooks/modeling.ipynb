# %%
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 import sklearn
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data = pd.read_csv("data/merged.csv", index_col=[0])

# %% [markdown]
# ## Useful EDA

# %%
data['ds_pm_pred'].hist(by=data['state_acronym'], sharey=True, sharex=True)
# Out:
# array([[<Axes: title={'center': 'AZ'}>, <Axes: title={'center': 'CA'}>],
#        [<Axes: title={'center': 'NV'}>, <Axes: title={'center': 'OR'}>]],
#       dtype=object)

# %%
data
# Out:
#     Unnamed: 0_x  year  statefips  countyfips  ds_pm_pred  ds_pm_stdd
# 0              0  2011          6        6001    9.900472    1.247647  \
# 1              3  2011          6        6007    7.720789    1.292654
# 2              6  2011          6        6013    9.463319    1.227127
# 3              8  2011          6        6017    7.378507    1.279765
# 4              9  2011          6        6019   13.338245    1.677026
# ..           ...   ...        ...         ...         ...         ...
# 66            11  2011          4        4021    7.527964    1.094924
# 67            13  2011          4        4025    5.993673    1.014849
# 68            14  2011          4        4027    7.216143    0.979470
# 69             1  2011         32       32003    8.345318    1.404623
# 70            14  2011         32       32031    7.210372    1.297015
#
#    state_acronym          county_name  Unnamed: 0_y
# 0             CA       Alameda County             0  \
# ...
